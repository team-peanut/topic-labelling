# %% [markdown]
# # Topic extraction

# %%
import psycopg2
from time import time
import nltk
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np

n_samples = 200000
n_features = 500

# %%
print("Connecting to DB...")
conn = psycopg2.connect("dbname='peanut_prod' user='mezis' host='frolic.local' password='av85ck4g'")
cur = conn.cursor()

print("Loading dataset...")
t0 = time()
cur.execute(f"""
    SELECT CONCAT_WS(' ', title, body) AS text
    FROM post p
    JOIN users u ON u.id = p.author_id
    --JOIN post_stats ps ON ps.id = p.id AND ps.view_count > 50
    WHERE TRUE
      AND u.account_status = 'active'
      AND p.status = 'active'
    ORDER BY p.id DESC
    LIMIT {n_samples}
""")
data_samples = [row[0] for row in cur.fetchall()]

print("done in %0.3fs." % (time() - t0))
print("%d samples" % len(data_samples))
# Out:
# Connecting to DB...
# Loading dataset...
# done in 0.989s.
# 200000 samples

# %%
print("Preparing text preprocessing...")
import re

t0 = time()
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')

class MyPreprocessor:
    def __call__(self, doc):
        return doc.lower()

class MyTokenizer:
    def __init__(self):
        self.wnl = nltk.stem.WordNetLemmatizer()
        self.stopwords = frozenset(
            nltk.corpus.stopwords.words('english') + """
                n't
                anyone
                everyone
                feel like want get
            """.split()
        )
        self.re = re.compile(r"[a-z0-9]")
        
    def __call__(self, doc):
        return [token for token in [self.filter(token) for token in self.tokenize(doc)] if token]
    
    def tokenize(self, doc):
        return nltk.word_tokenize(doc.lower());
    
    def filter(self, token):
        if token in self.stopwords:
            return
        if not self.re.match(token):
            return
        return self.wnl.lemmatize(token)
        

print("done in %0.3fs." % (time() - t0))

test_string = "My mother-in-law isn't, really, as lovely as I'd like her to be."
print(MyTokenizer()(test_string))

print(nltk.pos_tag(nltk.word_tokenize('let me know')))
      
# for doc in data_samples[-3:]:
#     print(MyTokenizer()(doc))
# Out:
# Preparing text preprocessing...
# done in 0.146s.
# [nltk_data] Downloading package punkt to /home/mezis/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/mezis/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/mezis/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/mezis/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# ['mother-in-law', 'really', 'lovely']
# [('let', 'VB'), ('me', 'PRP'), ('know', 'VB')]

# %%
print("Extracting 2-grams...")
gram2 = CountVectorizer(max_df=0.90, min_df=0.001,
                                max_features=n_features,
                                stop_words=None,
                                ngram_range=(2,2),
                                tokenizer=MyTokenizer())
t0 = time()
# %time tf = gram2.fit_transform(data_samples)
print("done in %0.3fs." % (time() - t0))
# Out:
# Extracting 2-grams...
# CPU times: user 1min 40s, sys: 272 ms, total: 1min 40s
# Wall time: 1min 40s
# done in 100.775s.

# %%
counts = np.sum(tf, axis=0)
terms = gram2.get_feature_names()
terms_counts = []
for k in range(n_features):
    terms_counts.append((terms[k], counts[0,k]))
terms_counts.sort(key=lambda t: -t[1])
terms_counts
# Out:
# [('month old', 13725),
#  ('year old', 6994),
#  ('little one', 5601),
#  ('week pregnant', 5135),
#  ('first time', 4587),
#  ('6 month', 3957),
#  ('week old', 3766),
#  ('4 month', 3251),
#  ('3 month', 3071),
#  ('wan na', 2899),
#  ('go back', 2715),
#  ('would love', 2646),
#  ('last night', 2597),
#  ('baby girl', 2534),
#  ('5 month', 2437),
#  ('2 week', 2417),
#  ('let know', 2393),
#  ('6 week', 2377),
#  ('stay home', 2328),
#  ('hi lady', 2316),
#  ('little girl', 2231),
#  ('2 year', 2113),
#  ('back work', 2080),
#  ('2 month', 2057),
#  ('little boy', 1983),
#  ('gon na', 1954),
#  ('7 month', 1951),
#  ('week ago', 1932),
#  ('8 month', 1927),
#  ('9 month', 1865),
#  ('play date', 1851),
#  ('last week', 1844),
#  ('12 week', 1820),
#  ('hey lady', 1801),
#  ('thank much', 1801),
#  ('need help', 1799),
#  ('3 day', 1742),
#  ('please help', 1735),
#  ('baby boy', 1725),
#  ('every time', 1718),
#  ('2 day', 1712),
#  ('old baby', 1697),
#  ('3 week', 1639),
#  ('every day', 1628),
#  ('even though', 1613),
#  ('c section', 1612),
#  ('8 week', 1559),
#  ('next week', 1553),
#  ('need advice', 1531),
#  ('pregnancy test', 1529),
#  ('5 week', 1479),
#  ('month ago', 1456),
#  ('3 year', 1447),
#  ('1 year', 1433),
#  ('first baby', 1416),
#  ('car seat', 1374),
#  ('make sure', 1374),
#  ('mother day', 1372),
#  ('day ago', 1324),
#  ('7 week', 1316),
#  ('thanks advance', 1314),
#  ('10 month', 1268),
#  ('mom friend', 1249),
#  ('4 day', 1244),
#  ('full time', 1243),
#  ('two week', 1243),
#  ('really bad', 1227),
#  ('4 week', 1222),
#  ('fall asleep', 1201),
#  ('birth control', 1200),
#  ('20 week', 1193),
#  ('week scan', 1191),
#  ('breast milk', 1176),
#  ('5 day', 1164),
#  ('hey mama', 1161),
#  ('got pregnant', 1160),
#  ('dont know', 1151),
#  ('year ago', 1150),
#  ('ovulation test', 1149),
#  ('due date', 1143),
#  ('maternity leave', 1141),
#  ('found pregnant', 1116),
#  ('couple day', 1114),
#  ('baby shower', 1108),
#  ('day late', 1106),
#  ('old son', 1099),
#  ('first pregnancy', 1090),
#  ('else experienced', 1088),
#  ('hard time', 1086),
#  ('giving birth', 1070),
#  ('going back', 1062),
#  ('come back', 1058),
#  ('time mom', 1057),
#  ('old daughter', 1040),
#  ('sleep night', 1035),
#  ('work home', 1009),
#  ('home mom', 1005),
#  ('little bit', 987),
#  ('baby sleep', 986),
#  ('back sleep', 982),
#  ('thought would', 974),
#  ('morning sickness', 949),
#  ('last month', 941),
#  ('back pain', 936),
#  ('10 week', 930),
#  ('take care', 924),
#  ('2 hour', 918),
#  ('4 year', 910),
#  ('advice would', 908),
#  ('one day', 907),
#  ('pretty much', 901),
#  ('two day', 894),
#  ('advice please', 890),
#  ('really need', 886),
#  ('time day', 881),
#  ('potty training', 874),
#  ('last year', 853),
#  ('anybody else', 850),
#  ('new friend', 839),
#  ('9 week', 837),
#  ('baby born', 837),
#  ('ever since', 830),
#  ('came back', 823),
#  ('new year', 822),
#  ('long take', 815),
#  ('single mom', 815),
#  ('best friend', 809),
#  ('go away', 790),
#  ('couple week', 781),
#  ('hi mama', 780),
#  ('would great', 780),
#  ('11 month', 777),
#  ('help please', 777),
#  ('go sleep', 764),
#  ('baby food', 758),
#  ('new mom', 755),
#  ('else experience', 754),
#  ('5 year', 752),
#  ('time mum', 752),
#  ('hey guy', 750),
#  ('next month', 748),
#  ('pregnant first', 746),
#  ('know good', 745),
#  ('mommy friend', 745),
#  ('another baby', 740),
#  ('every night', 738),
#  ('16 week', 736),
#  ('breast pump', 736),
#  ('please tell', 735),
#  ('anything else', 725),
#  ('really struggling', 725),
#  ('sleep regression', 724),
#  ('gave birth', 722),
#  ('day week', 721),
#  ('please let', 721),
#  ('month pregnant', 710),
#  ('early pregnancy', 706),
#  ('breast feeding', 703),
#  ('11 week', 697),
#  ('baby 2', 687),
#  ('stretch mark', 687),
#  ('blood test', 686),
#  ('trying conceive', 686),
#  ('give birth', 685),
#  ('last time', 685),
#  ('mental health', 683),
#  ('3 hour', 681),
#  ('everything going', 672),
#  ('something wrong', 670),
#  ('doctor said', 666),
#  ('really know', 666),
#  ('milk supply', 663),
#  ('one year', 662),
#  ('two year', 661),
#  ('good morning', 653),
#  ('go bed', 651),
#  ('last day', 650),
#  ('come home', 649),
#  ('week today', 645),
#  ('someone else', 643),
#  ('getting pregnant', 642),
#  ('make friend', 640),
#  ('yr old', 640),
#  ('first trimester', 635),
#  ('hospital bag', 632),
#  ('18 month', 631),
#  ('baby clothes', 630),
#  ('long time', 629),
#  ('old boy', 626),
#  ('hello lady', 621),
#  ('really hard', 614),
#  ('past week', 605),
#  ('two month', 604),
#  ('took test', 599),
#  ('36 week', 597),
#  ('even know', 596),
#  ('back normal', 595),
#  ('working home', 594),
#  ('first child', 588),
#  ('hi guy', 587),
#  ('need friend', 587),
#  ('baby first', 586),
#  ('day old', 581),
#  ('else baby', 579),
#  ('part time', 578),
#  ('social medium', 576),
#  ('wanted know', 576),
#  ('let go', 573),
#  ('know going', 570),
#  ('would recommend', 568),
#  ('greatly appreciated', 564),
#  ('wondering else', 564),
#  ('social distancing', 563),
#  ('6 day', 562),
#  ('looking advice', 561),
#  ('little man', 552),
#  ('next day', 551),
#  ('second baby', 551),
#  ('something else', 550),
#  ('family member', 547),
#  ('faint line', 546),
#  ('boy girl', 545),
#  ('baby group', 542),
#  ('family friend', 539),
#  ('37 week', 537),
#  ('valentine day', 536),
#  ('implantation bleeding', 535),
#  ('know baby', 534),
#  ('mother law', 533),
#  ('would go', 533),
#  ('old sleep', 527),
#  ('trying find', 526),
#  ('high risk', 525),
#  ('night time', 525),
#  ('help baby', 524),
#  ('lower back', 524),
#  ('sleep training', 524),
#  ('would appreciated', 523),
#  ('every single', 522),
#  ('know else', 518),
#  ('tummy time', 516),
#  ('13 week', 512),
#  ('one else', 512),
#  ('time go', 509),
#  ('15 month', 504),
#  ('meet new', 504),
#  ('almost 2', 503),
#  ('since baby', 502),
#  ('husband work', 501),
#  ('32 week', 499),
#  ('nap day', 499),
#  ('looking forward', 497),
#  ('28 week', 494),
#  ('sorry long', 492),
#  ('many time', 490),
#  ('thanks x', 490),
#  ('thank thank', 489),
#  ('throughout day', 489),
#  ('really good', 488),
#  ('30 week', 486),
#  ('pregnancy symptom', 486),
#  ('going crazy', 484),
#  ('35 week', 481),
#  ('love hear', 481),
#  ('1 month', 480),
#  ('new group', 480),
#  ('would really', 480),
#  ('time baby', 478),
#  ('hi new', 477),
#  ('see baby', 477),
#  ('tried everything', 477),
#  ('14 week', 475),
#  ('baby baby', 475),
#  ('make new', 475),
#  ('make sense', 475),
#  ('post partum', 474),
#  ('tip trick', 472),
#  ('please share', 471),
#  ('know need', 470),
#  ('many people', 470),
#  ('38 week', 469),
#  ('day today', 464),
#  ('much appreciated', 464),
#  ('went back', 464),
#  ('6 year', 460),
#  ('keep getting', 460),
#  ('thank advance', 459),
#  ('long story', 458),
#  ('taking care', 458),
#  ('friend family', 455),
#  ('couple month', 451),
#  ('every hour', 451),
#  ('34 week', 449),
#  ('first birthday', 448),
#  ('spend time', 448),
#  ('corona virus', 447),
#  ('guy think', 447),
#  ('day day', 446),
#  ('go work', 445),
#  ('last couple', 445),
#  ('period due', 445),
#  ('time night', 445),
#  ('week baby', 445),
#  ('birthday party', 444),
#  ('long post', 444),
#  ('side effect', 441),
#  ('take baby', 440),
#  ('health visitor', 439),
#  ('join u', 439),
#  ('new app', 439),
#  ('happy mother', 438),
#  ('would say', 434),
#  ('think would', 431),
#  ('work full', 431),
#  ('15 week', 427),
#  ('18 week', 427),
#  ('33 week', 427),
#  ('another one', 427),
#  ('bed time', 425),
#  ('one thing', 425),
#  ('need go', 424),
#  ('new baby', 424),
#  ('old little', 424),
#  ('right side', 424),
#  ('night feed', 423),
#  ('know could', 422),
#  ('child support', 421),
#  ('love meet', 421),
#  ('clear blue', 420),
#  ('every month', 420),
#  ('sippy cup', 420),
#  ('16 month', 419),
#  ('sex drive', 419),
#  ('cow milk', 418),
#  ('mummy friend', 416),
#  ('baby 3', 415),
#  ('put baby', 414),
#  ('would greatly', 414),
#  ('month sleep', 413),
#  ('feeling really', 411),
#  ('3 time', 410),
#  ('would help', 409),
#  ('10 day', 408),
#  ('give advice', 408),
#  ('14 month', 407),
#  ('day period', 407),
#  ('know people', 406),
#  ('17 week', 405),
#  ('know would', 405),
#  ('19 week', 403),
#  ('4 hour', 403),
#  ('little guy', 403),
#  ('middle name', 403),
#  ('pretty sure', 403),
#  ('month baby', 402),
#  ('night sleep', 401),
#  ('anything help', 400),
#  ('pregnant woman', 400),
#  ('give baby', 399),
#  ('middle night', 399),
#  ('baby dust', 398),
#  ('left side', 397),
#  ('month pp', 397),
#  ('13 month', 396),
#  ('lose weight', 396),
#  ('last 2', 395),
#  ('tip advice', 395),
#  ('finally got', 394),
#  ('take bottle', 394),
#  ('baby know', 392),
#  ('could use', 392),
#  ('mucus plug', 392),
#  ('baby come', 391),
#  ('braxton hick', 391),
#  ('almost 3', 390),
#  ('one month', 390),
#  ('1st birthday', 389),
#  ('moses basket', 389),
#  ('would nice', 389),
#  ('trying figure', 388),
#  ('baby move', 387),
#  ('25 week', 386),
#  ('time around', 386),
#  ('tip help', 385),
#  ('know much', 383),
#  ('first period', 381),
#  ('let see', 381),
#  ('month still', 381),
#  ('baby due', 380),
#  ('wish could', 380),
#  ('hour day', 379),
#  ('know anything', 379),
#  ('something similar', 379),
#  ('doctor appointment', 378),
#  ('breast feed', 377),
#  ('day night', 377),
#  ('single mum', 377),
#  ('week 3', 377),
#  ('first month', 376),
#  ('second pregnancy', 376),
#  ('weight gain', 375),
#  ('baby daddy', 374),
#  ('recommend good', 374),
#  ('baby monitor', 372),
#  ('right away', 372),
#  ('wanted share', 372),
#  ('week tomorrow', 372),
#  ('around house', 371),
#  ('past day', 371),
#  ('getting worse', 370),
#  ('pregnant second', 370),
#  ('sleeping night', 370),
#  ('10 year', 368),
#  ('12 month', 368),
#  ('baby 6', 368),
#  ('lot people', 368),
#  ('since last', 368),
#  ('week 2', 368),
#  ('whole time', 368),
#  ('week first', 367),
#  ('week pp', 367),
#  ('first day', 366),
#  ('similar situation', 366),
#  ('old still', 365),
#  ('second child', 365),
#  ('2 kid', 364),
#  ('24 week', 364),
#  ('trying baby', 364),
#  ('child care', 363),
#  ('need vent', 363),
#  ('wanted see', 363),
#  ('af due', 362),
#  ('test negative', 362),
#  ('21 week', 361),
#  ('anybody know', 361),
#  ('every 2', 361),
#  ('week still', 361),
#  ('looking mom', 360),
#  ('one know', 360),
#  ('need someone', 359),
#  ('recently started', 359),
#  ('new area', 358),
#  ('hey momma', 357),
#  ('midwife appointment', 357),
#  ('multiple time', 357),
#  ('covid 19', 356),
#  ('story short', 356),
#  ('39 week', 355),
#  ('positive test', 355),
#  ('could help', 352),
#  ('7 day', 351),
#  ('need know', 351),
#  ('said would', 351),
#  ('blood pressure', 350),
#  ('day time', 350),
#  ('pregnant baby', 349),
#  ('26 week', 348),
#  ('new born', 348),
#  ('31 week', 347),
#  ('day really', 347),
#  ('need new', 347),
#  ('thank x', 347),
#  ('weight loss', 347),
#  ('ca wait', 346),
#  ('know one', 345),
#  ('new mum', 345),
#  ('feed baby', 344),
#  ('missed period', 344),
#  ('past couple', 344),
#  ('baby need', 343),
#  ('week 4', 343),
#  ('looking friend', 342),
#  ('back home', 341),
#  ('third trimester', 341),
#  ('home work', 340),
#  ('three month', 340),
#  ('maternity clothes', 339),
#  ('say anything', 339),
#  ('7 year', 338),
#  ('nap time', 338),
#  ('baby weight', 336),
#  ('looking new', 335),
#  ('universal credit', 335),
#  ('blood work', 334),
#  ('care baby', 333),
#  ('late period', 333),
#  ('wait till', 333),
#  ('keep going', 332),
#  ('negative test', 332),
#  ('boy name', 331),
#  ('would take', 331),
#  ('hour night', 330),
#  ('last two', 330),
#  ('mom need', 330),
#  ('old girl', 330),
#  ('share experience', 330),
#  ('start trying', 329),
#  ('cycle day', 328),
#  ('two kid', 328),
#  ('similar experience', 325)]

# %%
print("Extracting 3-grams...")
gram3 = CountVectorizer(max_df=0.90, min_df=0.001,
                                max_features=n_features,
                                stop_words=None,
                                ngram_range=(3,3),
                                tokenizer=MyTokenizer())
t0 = time()
# %time tf = gram3.fit_transform(data_samples)
print("done in %0.3fs." % (time() - t0))
# Out:
# Extracting 3-grams...
# CPU times: user 1min 42s, sys: 360 ms, total: 1min 42s
# Wall time: 1min 42s
# done in 102.369s.

# %%
counts = np.sum(tf, axis=0)
terms = gram3.get_feature_names()
terms_counts = []
print(len(terms))
print(counts.shape)
for k in range(len(terms)):
    terms_counts.append((terms[k], counts[0,k]))
terms_counts.sort(key=lambda t: -t[1])
terms_counts
# Out:
# 72
# (1, 72)
# [('6 month old', 1420),
#  ('4 month old', 1327),
#  ('3 month old', 1245),
#  ('2 year old', 1205),
#  ('5 month old', 1119),
#  ('1 year old', 1104),
#  ('8 month old', 974),
#  ('7 month old', 935),
#  ('stay home mom', 931),
#  ('9 month old', 918),
#  ('month old baby', 893),
#  ('first time mom', 889),
#  ('go back work', 795),
#  ('3 year old', 779),
#  ('2 month old', 769),
#  ('10 month old', 716),
#  ('first time mum', 677),
#  ('please let know', 661),
#  ('going back work', 539),
#  ('one year old', 516),
#  ('12 week scan', 495),
#  ('4 year old', 487),
#  ('20 week scan', 480),
#  ('11 month old', 466),
#  ('week old baby', 441),
#  ('month old son', 437),
#  ('month old daughter', 433),
#  ('3 week old', 430),
#  ('6 week old', 429),
#  ('happy mother day', 423),
#  ('work full time', 422),
#  ('year old son', 416),
#  ('year old daughter', 410),
#  ('go back sleep', 368),
#  ('would greatly appreciated', 359),
#  ('long story short', 349),
#  ('7 week old', 342),
#  ('2 week ago', 328),
#  ('month old sleep', 328),
#  ('two year old', 321),
#  ('would love meet', 319),
#  ('year old boy', 311),
#  ('2 week old', 308),
#  ('18 month old', 307),
#  ('15 month old', 300),
#  ('week pregnant first', 293),
#  ('week 3 day', 292),
#  ('would love hear', 292),
#  ('5 year old', 289),
#  ('make new friend', 289),
#  ('month sleep regression', 282),
#  ('week 4 day', 282),
#  ('1 month old', 278),
#  ('5 week old', 275),
#  ('4 week old', 269),
#  ('week 5 day', 257),
#  ('8 week old', 255),
#  ('sorry long post', 255),
#  ('old baby girl', 243),
#  ('week 2 day', 242),
#  ('lower back pain', 240),
#  ('16 month old', 239),
#  ('6 week pregnant', 239),
#  ('last couple day', 236),
#  ('baby 6 month', 230),
#  ('happy new year', 227),
#  ('would much appreciated', 224),
#  ('10 week old', 221),
#  ('every 2 hour', 220),
#  ('month old still', 220),
#  ('almost 2 year', 218),
#  ('took pregnancy test', 213)]
